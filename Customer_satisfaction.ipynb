# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Reading dataset
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.shape
# Out:
# (103904, 25)

# %%
test_data.shape
# Out:
# (25976, 25)

# %%
train_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
train_data.head(5)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# - Deleting all columns with no valuable information ('Unnamed: 0' and 'id')

# %%
train_data = train_data.drop(['Unnamed: 0','id'], axis = 1)
test_data = test_data.drop(['Unnamed: 0','id'], axis = 1)

# %% [markdown]
# - converting all categorial data into numeric

# %%
le = LabelEncoder()
train_data['Gender'] = le.fit_transform(train_data['Gender'])
train_data['Customer Type'] = le.fit_transform(train_data['Customer Type'])
train_data['Type of Travel'] = le.fit_transform(train_data['Type of Travel'])
train_data['Class'] = le.fit_transform(train_data['Class'])
train_data['satisfaction'] = le.fit_transform(train_data['satisfaction'])

# %%
train_data.head(5)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
le = LabelEncoder()
test_data['Gender'] = le.fit_transform(test_data['Gender'])
test_data['Customer Type'] = le.fit_transform(test_data['Customer Type'])
test_data['Type of Travel'] = le.fit_transform(test_data['Type of Travel'])
test_data['Class'] = le.fit_transform(test_data['Class'])
test_data['satisfaction'] = le.fit_transform(test_data['satisfaction'])

# %%
test_data.head(5)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              0   52               0      1              160
# 1       0              0   36               0      0             2863
# 2       1              1   20               0      1              192
# 3       1              0   44               0      0             3377
# 4       0              0   49               0      1             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              4  ...                       5
# ...

# %% [markdown]
# ## All Conversion
# a) For Gender
# - Male : 1
# - Female: 0
#
# b) For Customer Type
# - Loyal Customer : 0
# - Disloyal Customer : 1
#
# c) For Type of Travel
# - Personal Travel : 1
# - Business Travel : 0
#
# d) Class
# - Eco Plus : 2
# - Eco : 1
# - Business : 0
#
# e) satisfaction
# - Satisfied : 1
# - Dissatisfied : 0

# %% [markdown]
# Checking for null values

# %%
train_data.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
train_data.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %% [markdown]
# Filling all the null values with median

# %%
train_data['Arrival Delay in Minutes'] = train_data['Arrival Delay in Minutes'].fillna(train_data['Arrival Delay in Minutes'].median())
test_data['Arrival Delay in Minutes'] = test_data['Arrival Delay in Minutes'].fillna(test_data['Arrival Delay in Minutes'].median())

# %%
train_data.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# Determining which features are skewed.

# %%
numeris_feature = train_data.select_dtypes(include=[np.number]).columns
skewness = train_data[numeris_feature].skew().sort_values(ascending=False)
features_to_log = skewness[skewness > 1].index.tolist()
print(features_to_log)
# Out:
# ['Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Customer Type', 'Flight Distance']

# %% [markdown]
# Apply logarithm to them

# %%
for features in features_to_log:
    train_data[features] = np.log1p(train_data[features])
    test_data[features] = np.log1p(test_data[features])

# %% [markdown]
# split the dataset into features and target.

# %%
x_train = train_data.drop(columns= ['satisfaction'])
y_train = train_data['satisfaction'].to_numpy()
x_test = test_data.drop(columns= ['satisfaction'])
y_test = test_data['satisfaction'].to_numpy()

# %% [markdown]
# EDA - Exploratory Data Analysis

# %%
df = train_data
df
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            1       0.000000   13               1      2         6.133398
# 1            1       0.693147   25               0      0         5.463832
# 2            0       0.000000   26               0      0         7.041412
# 3            0       0.000000   25               0      0         6.333280
# 4            1       0.000000   61               0      0         5.370638
# ...        ...            ...  ...             ...    ...              ...
# 103899       0       0.693147   23               0      1         5.262690
# 103900       1       0.000000   49               0      0         7.761319
# 103901       1       0.693147   30               0      0         7.598900
# 103902       0       0.693147   22               0      1         6.908755
# 103903       1       0.000000   27               0      0         7.452402
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='satisfaction',palette=['red','yellow'])
plt.title('Distribution of Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Count')
plt.legend(['Dissatisfied',"Satisfied"])
plt.show()
# Out:
# C:\Users\amit3\AppData\Local\Temp\ipykernel_13976\2947290644.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='satisfaction',palette=['red','yellow'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Gender',palette=['red','yellow'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(['Male',"Female"])
plt.show()
# Out:
# C:\Users\amit3\AppData\Local\Temp\ipykernel_13976\3058444803.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Gender',palette=['red','yellow'])

# %%
f,ax=plt.subplots(1,2,figsize=(10,6))
df['Class'].value_counts().plot.bar(color=['Red','Green','Blue'],ax=ax[0])
ax[0].set_title('Number of passengers by Class')
ax[0].set_ylabel('Count')
sns.countplot(x='Class',hue='satisfaction',data=train_data,ax=ax[1],palette=['green','blue'])
ax[1].set_title('Class:Satisfied vs Not')
plt.legend(['Dissatisfied',"Satisfied"])
plt.show()

# %%
fig,axs = plt.subplots(2,2,figsize=(14, 14))
cols=['Gender', 'Customer Type', 'Type of Travel', 'Class']
c=0
for i in range(2):
  for j in range(2):
    sns.countplot(data=df,x=cols[c],hue='satisfaction',ax=axs[i][j])
    axs[i][j].set_title('Customer Satisafaction as per {}'.format(cols[c]))
    axs[i][j].legend(['Dissatisfied',"Satisfied"])
    c+=1

# %% [markdown]
# Distribution of Some variables

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Flight Distance'],bins=30,kde=True)
plt.title('Distribution of Flight Distance Length')
plt.xlabel('Length of Flight')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Correlation

# %%
sns.heatmap(df.corr(),annot=True,cmap='OrRd',linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches(20,20)
plt.show()

# %% [markdown]
# Model
#
# Dcision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import f1_score, roc_auc_score


def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    y_probability = model.predict_proba(x_test)[:,1]
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    
    print(f'Accuracy: {accuracy} \nF1-Score:{f1} \nROC-AUC:{roc_auc}')

# %%
# Vanilla Decision Tree
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
print('Vanilla Decision Tree\n')
print('Metrices on train data:')
print('---'*8)
evaluate_model(dt_model,x_train,y_train)
print('\nMetrices on test:')
print('--'*9)
evaluate_model(dt_model,x_test,y_test)
# Out:
# Vanilla Decision Tree
#
# Metrices on train data:
# ------------------------
# Accuracy: 1.0
# F1-Score:1.0
# ROC-AUC:1.0
#
# Metrices on test:
# ------------------
# Accuracy: 0.947682476131814
# F1-Score:0.940460021905805
# ROC-AUC:0.9469821587085671

# %%
# 2. Decision Tree with CV
param_grid = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [3, 5, 10, 15],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 3, 5, 10]
}

grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5, scoring='roc_auc')
grid_search.fit(x_train, y_train)
best_dt_model = grid_search.best_estimator_
print("Decision Tree with CV:\n")
print("metrics on train:")

evaluate_model(best_dt_model, x_train, y_train)
print("\nmetrics on test:")
evaluate_model(best_dt_model, x_test, y_te
               st)
# Out:
# C:\Users\amit3\AppData\Roaming\Python\Python312\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Decision Tree with CV:
#
# metrics on train:
# Accuracy: 0.9507526178010471
# F1-Score:0.9415032866533295
# ROC-AUC:0.9464970723279796
#
# metrics on test:
# Accuracy: 0.9474899907607022
# F1-Score:0.9385585585585585
# ROC-AUC:0.9438061118831543

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

def plot_roc_curve(model, x_test, y_test, model_name):
    y_proba = model.predict_proba(x_test)[:, 1]
    
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    auc_score = roc_auc_score(y_test, y_proba)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='salmon', label=f'ROC Curve (AUC = {auc_score:.4f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line for random guessing
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {model_name}')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

plot_roc_curve(dt_model, x_test, y_test, 'Vanilla Decision Tree')
plot_roc_curve(best_dt_model, x_test, y_test, 'Decision Tree with CV')

# %%
# Vanilla Decision Tree
y_proba_dt = dt_model.predict_proba(x_test)[:, 1]
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_proba_dt)
auc_score_dt = roc_auc_score(y_test, y_proba_dt)

# Decision Tree with CV
y_proba_dtcv = best_dt_model.predict_proba(x_test)[:, 1]
fpr_dtcv, tpr_dtcv, _ = roc_curve(y_test, y_proba_dtcv)
auc_score_dtcv = roc_auc_score(y_test, y_proba_dtcv)

# both ROC curves
plt.figure(figsize=(8, 6))
plt.plot(fpr_dt, tpr_dt, color='salmon', label=f'Vanilla Decision Tree (AUC = {auc_score_dt:.4f})', linewidth=2)
plt.plot(fpr_dtcv, tpr_dtcv, color='cyan', label=f'Decision Tree with CV (AUC = {auc_score_dtcv:.4f})', linewidth=2)

# random guessing
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', linewidth=1.5)

plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve Comparison', fontsize=16)
plt.legend(loc='lower right', fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
feature_importances = best_dt_model.feature_importances_
feature_names = x_train.columns

importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(8, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='cyan')
plt.xlabel('Importance')
plt.title('Decision Tree Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(25, 10))
plot_tree(best_dt_model, feature_names=feature_names, class_names=['Unsatisfied', 'Satisfied'], filled=True, max_depth=3)
plt.show()
